# %% [markdown]
# # Machine Learning - Mean Median Mode

# %% [markdown]
# Mean

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.mean(speed)

print("Mean= ", x)
# Out:
# Mean=  89.76923076923077

# %% [markdown]
# Median

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.median(speed)

print("Median= ", x)
# Out:
# Median=  87.0

# %%
import numpy

speed = [99,86,87,88,86,103,87,94,78,77,85,86]

x = numpy.median(speed)

print("Median= ", x)
# Out:
# Median=  86.5

# %% [markdown]
# Mode

# %%
from scipy import stats

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = stats.mode(speed)

print("Mode= ", x)
# Out:
# Mode=  ModeResult(mode=array([86]), count=array([3]))
# C:\Users\skdas\AppData\Local\Temp\ipykernel_22720\2317844969.py:5: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   x = stats.mode(speed)

# %% [markdown]
# # Machine Learning - Standard Deviation

# %%
import numpy

speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)

print("Standard Deviation= ", x)
# Out:
# Standard Deviation=  0.9035079029052513

# %%
import numpy

speed = [32,111,138,28,59,77,97]

x = numpy.std(speed)

print("Standard Deviation= ", x)
# Out:
# Standard Deviation=  37.84501153334721

# %% [markdown]
# Variance(another number that indicates how spread out the values are.)

# %%
import numpy

speed = [32,111,138,28,59,77,97]

x = numpy.var(speed)

print("Variance= ", x)
# Out:
# Variance=  1432.2448979591834

# %% [markdown]
# # Machine Learning - Percentiles

# %%
import numpy

ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 75)

print("Percentile= ", x)
# Out:
# Percentile=  43.0

# %%
import numpy

ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 90)

print("Percentile= ", x)
# Out:
# Percentile=  61.0

# %% [markdown]
# # Machine Learning - Data Distribution

# %%
import numpy

x = numpy.random.uniform(0.0, 5.0, 250)

print(x)
# Out:
# [4.49779037 2.56147318 1.12804677 0.40602092 4.71750061 2.34749135
#  2.44005563 4.68417492 4.58106008 4.16070109 0.31477765 1.09794448
#  3.94344462 3.07314318 4.25846496 0.08041665 0.20304094 3.92629468
#  4.83142359 2.06599594 3.89197894 4.95926276 1.31033575 0.53726164
#  0.73027509 4.84502568 0.20082605 0.8290023  4.39357767 4.72957794
#  0.2675318  1.56049494 1.73961991 4.28655301 1.69538489 0.85207095
#  3.79601609 3.64367597 3.89281097 4.46495988 4.74567443 2.64957738
#  0.27485253 3.66528682 1.49595964 4.92827849 3.42531711 2.4251779
#  2.07747788 1.13563991 1.69854516 4.5936806  0.98105093 0.32204995
#  2.24775461 1.00766511 0.63944764 4.70046995 0.411143   1.2240194
#  3.82796771 3.05759409 2.46665872 4.53640696 2.32503734 4.50969985
#  2.15933645 1.73995627 1.18212864 1.5849615  0.55013266 3.38705223
#  2.18888279 3.31264899 3.53037779 3.2598342  3.8722627  4.63792306
#  3.94069079 3.29380019 4.64019992 3.6825155  4.28355977 0.16566166
#  1.34293223 3.53690913 4.10015127 1.9073703  2.54952984 2.29668733
#  3.29691587 3.36178802 3.4718454  3.17561323 0.32340024 2.43996531
#  0.98325503 3.59836071 1.02335371 3.60961545 4.26668096 1.39312665
#  0.53496262 0.3960423  4.07085116 3.34854426 1.56267378 3.56487586
#  4.82640089 2.75877947 0.4811131  2.96375953 1.33729429 0.46681192
#  0.01291701 1.38060575 1.87403239 4.11696062 2.0407253  0.97815023
#  0.56681289 1.8915797  0.26713587 1.85415495 1.75766719 0.34875694
#  2.68134194 2.69502863 4.73068122 0.97244991 3.18406722 0.84425817
#  1.91153901 1.53274031 1.66709395 2.47525682 2.04506813 4.31556522
#  2.83947659 3.31131423 1.43123941 2.21690875 2.69329723 1.05491085
#  0.83804558 0.98528533 0.93607487 3.27344388 3.18973163 4.9175958
#  2.20399688 1.96404241 2.5085655  1.97787332 1.96763992 3.51548212
#  3.89447068 1.72601703 3.76277964 0.34373903 2.24157865 2.14619848
#  1.99516736 3.68662713 3.57093683 1.16395158 4.08752101 1.56740301
#  4.70807769 2.04671637 1.18827062 1.85235178 4.5040181  3.8959121
#  0.79481872 4.01551011 0.04994976 1.14687962 3.89843819 4.85845089
#  0.35592413 3.56453153 3.04261797 4.55792563 4.63327209 1.74405327
#  1.62543455 0.73885646 4.06035242 3.17121293 2.52065415 2.27621446
#  4.61894264 2.92496982 3.96218876 2.85217467 2.36361083 3.68004495
#  1.02500269 3.83894825 1.23644232 2.23748018 3.45953018 4.12426781
#  3.43294973 1.37207344 2.9432935  1.19364197 4.22529181 2.65876239
#  4.95298014 1.41753039 2.64611015 4.4295543  4.36629874 4.32310944
#  1.62764223 1.69248116 3.89763111 4.18396881 3.72662975 0.62591253
#  3.14946845 0.58145441 3.04045228 4.47798949 1.24582039 3.79350901
#  4.57752365 0.60538813 0.93622937 3.97648815 1.80534318 1.71539076
#  2.7297955  0.67996448 2.76336543 4.62007019 3.85430731 1.25759172
#  4.62247402 3.64595413 2.9609327  0.94450996 2.21850582 3.94682953
#  1.6200501  0.10847883 4.70234502 1.75231534]

# %% [markdown]
# Histogram

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5)
plt.show()

# %% [markdown]
# Big Data Distributions

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 100000)

plt.hist(x, 100)
plt.show()

# %% [markdown]
# # Machine Learning - Normal Data Distribution

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %% [markdown]
# # Machine Learning - Scatter Plot

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Random Data Distributions

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()
